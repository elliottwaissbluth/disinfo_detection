# %% [markdown]
# ## For use after intra_links.py has been run

# %%
import pickle
from pathlib import Path
import pandas as pd
pd.set_option('display.max_rows', 100)

def generate_dataframe(truncate_lists = False):
    '''
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ARGUMENTS ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ #
    truncate_lists : False or int
        - if False, full list of domains in dataframe remains
        - if True, each domain list is truncated to len(<domain list>) <= truncate_lists
    '''

    df = pd.DataFrame(columns=['index', 'site', 'num_links', 'link_dict'])

    with open('url_key_sp.pkl', 'rb') as f:
        key_dict = pickle.load(f)
    f.close()

    for i in range(100):
        try:
            path = Path.cwd().parent / 'link_lists' / (str(i) + '.pkl')
            with open(path, 'rb') as f:
                link_list = pickle.load(f)
            f.close()
        except:
            print('{}.pkl not present'.format(i))
            continue

        link_list = list(set(link_list)) # some lists have repeat domains
        link_list = [x for x in link_list if x] # some have empty strings
        if truncate_lists:
            link_list = link_list[-1*truncate_lists+1:]

        link_dict = {}
        for idx, link in enumerate(link_list):
            link_dict[idx] = link
        link_dict[idx+1] = key_dict[i] # add the original site to the link_dict

        df = df.append(
            {'index' : i,
            'site' : key_dict[i],
            'num_links' : len(link_dict),
            'link_dict': link_dict},
            ignore_index=True, 
        )

    return df

df = generate_dataframe(truncate_lists=100)

df.sort_values(by=['index']).reset_index(inplace=True)
df.head(100)
# Out:
# 4.pkl not present
# 5.pkl not present
# 8.pkl not present
# 13.pkl not present
# 15.pkl not present
# 23.pkl not present
# 26.pkl not present
# 39.pkl not present
# 44.pkl not present
# 45.pkl not present
# 48.pkl not present
# 51.pkl not present
# 52.pkl not present
# 53.pkl not present
# 57.pkl not present
# 61.pkl not present
# 63.pkl not present
# 65.pkl not present
# 73.pkl not present
# 76.pkl not present
# 85.pkl not present
# 86.pkl not present
# 87.pkl not present
# 88.pkl not present
# 89.pkl not present
# 90.pkl not present
# 91.pkl not present
# 92.pkl not present
# 93.pkl not present
# 94.pkl not present
# 95.pkl not present
# 96.pkl not present
# 97.pkl not present
# 98.pkl not present
# 99.pkl not present
#    index                                site num_links  \
# 0      0               http://dailyexpose.uk        65
# 1      1                   http://rumble.com        61
# 2      2                  http://harpers.org        67
# 3      3         http://kanekoa.substack.com        20
# 4      6              http://pattyporter.net         3
# 5      7          http://independentside.com        33
# 6      9       http://technofog.substack.com        18
# 7     10    http://alexberenson.substack.com        26
# 8     11                         http://t.me         1
# 9     12                    http://gettr.com        20
# 10    14                      http://apne.ws         1
# 11    16                  http://reuters.com       100
# 12    17                http://newyorker.com       100
# 13    18     http://stevekirsch.substack.com        22
# 14    19      http://publicinterestlegal.org        35
# 15    20           http://therenewal2022.org         7
# 16    21                   http://telegra.ph         1
# 17    22                  http://tinyurl.com        25
# 18    24                  http://twitter.com        58
# 19    25                      http://gao.gov        59
# 20    27                  http://madison.com        87
# 21    28     http://americanlibertyemail.com        14
# 22    29             http://voiceamerica.com       100
# 23    30          http://coachdavelive.video        72
# 24    31              http://jimmarchant.com         5
# 25    32                      http://khn.org        84
# 26    33                 http://tsionizm.com       100
# 27    34             http://freeworldnews.tv        96
# 28    35           http://podcasts.apple.com        83
# 29    36      http://rwmalonemd.substack.com        20
# 30    37            http://robertspencer.org        11
# 31    38         http://dossier.substack.com        21
# 32    40   http://fightbacklaw.pidoxapay.com         1
# 33    41   http://thekylebecker.substack.com        23
# 34    42           http://mobile.twitter.com        58
# 35    43          http://florida4america.org        11
# 36    46                    http://phmpt.org        29
# 37    47                         http://t.co         1
# 38    49     http://mielectionprotection.com         7
# 39    50        http://globalcovidsummit.org        46
# 40    54                   http://google.com        29
# 41    55                  http://voterga.org        40
# 42    56         http://americacanwetalk.org        33
# 43    58                       http://lc.org        44
# 44    59               http://abcnews.go.com       100
# 45    60      http://resistthemainstream.org        27
# 46    62                    http://axios.com        93
# 47    64                  http://medrxiv.org        69
# 48    66           http://dailynewsbreak.org        59
# 49    67              http://futurenews.news       100
# 50    68   http://starfirecodes.substack.com        21
# 51    69                  http://youtube.com        83
# 52    70       http://greenwald.substack.com        33
# 53    71        http://conservativebrief.com        28
# 54    72        http://jennycohn1.medium.com        71
# 55    74             http://highereddive.com        89
# 56    75             http://sidneypowell.com        31
# 57    77            http://documentcloud.org         4
# 58    78                 http://france24.com        16
# 59    79                      http://aps.edu        70
# 60    80             http://buzzfeednews.com       100
# 61    81            http://timesofisrael.com       100
# 62    82            http://americanfaith.com        36
# 63    83  http://myemail.constantcontact.com        51
# 64    84                   http://parler.com       100
#
#                                             link_dict
# 0   {0: 'https://dailyexpose.uk/author/rhoda-wilso...
# 1   {0: 'https://rumble.com/v113tdd-nba-playoffs-1...
# 2   {0: 'https://harpers.org/author/davidwonglouie...
# 3   {0: 'https://kanekoa.substack.com/p/exposing-a...
# 4   {0: 'https://www.pattyporter.net/home', 1: 'ht...
# 5   {0: 'https://independentside.com/biden-says-th...
# 6   {0: 'https://substack.com/signup?utm_source=su...
# 7   {0: 'https://alexberenson.substack.com/', 1: '...
# 8                                 {25: 'http://t.me'}
# 9   {0: 'https://about.gettr.com/press/football-le...
# 10                             {19: 'http://apne.ws'}
# 11  {0: 'https://www.reuters.com/world/asia-pacifi...
# 12  {0: 'https://subscribe.newyorker.com/subscribe...
# 13  {0: 'https://stevekirsch.substack.com/p/mits-d...
# 14  {0: 'https://publicinterestlegal.org/in-the-ne...
# 15  {0: 'https://www.therenewal2022.org/resources'...
# 16                           {6: 'http://telegra.ph'}
# 17  {0: 'https://tinyurl.com/app/myurls', 1: 'http...
# 18  {0: 'https://about.twitter.com/', 1: 'https://...
# 19  {0: 'https://www.gao.gov/about/what-gao-does/f...
# 20  {0: 'https://madison.com/news/should-medical-e...
# 21  {0: 'https://www.americanlibertyemail.com/cont...
# 22  {0: 'https://www.voiceamerica.com/show/3919/th...
# 23  {0: 'https://coachdavelive.video/video/3861/co...
# 24  {0: 'https://jimmarchant.com/donate/', 1: 'htt...
# 25  {0: 'https://khn.org/news/author/julie-rovner/...
# 26  {0: 'https://tsionizm.com/privacy-policy/', 1:...
# 27  {0: 'https://freeworldnews.tv/channel/riot-foo...
# 28  {0: 'https://www.apple.com/us/shop/goto/educat...
# 29  {0: 'https://substack.com/', 1: 'https://rwmal...
# 30  {0: 'https://robertspencer.org/privacy', 1: 'h...
# 31  {0: 'https://dossier.substack.com/p/bidenomics...
# 32          {20: 'http://fightbacklaw.pidoxapay.com'}
# 33  {0: 'https://thekylebecker.substack.com/p/dr-n...
# 34  {0: 'https://about.twitter.com/', 1: 'https://...
# 35  {0: 'https://florida4america.org/events/', 1: ...
# 36  {0: 'https://phmpt.org/wp-content/uploads/2021...
# 37                                {28: 'http://t.co'}
# 38  {0: 'https://www.mielectionprotection.com/', 1...
# 39  {0: 'https://globalcovidsummit.org/news/physic...
# 40  {0: 'https://workspace.google.com/products/gma...
# 41  {0: 'https://voterga.org/wp-content/uploads/20...
# 42  {0: 'https://americacanwetalk.org/category/acw...
# 43  {0: 'https://lc.org/project/pastors-and-church...
# 44  {0: 'https://abcnews.go.com/International/phot...
# 45  {0: 'https://resistthemainstream.org/', 1: 'ht...
# 46  {0: 'https://www.axios.com/abortion-ban-red-st...
# 47  {0: 'https://www.medrxiv.org/collection/medica...
# 48  {0: 'https://dailynewsbreak.org/what-happened-...
# 49  {0: 'https://futurenews.news/channel/macroaggr...
# 50  {0: 'https://starfirecodes.substack.com/archiv...
# 51  {0: 'https://www.youtube.com/c/MrBeast6000', 1...
# 52  {0: 'https://systemupdate.substack.com/p/video...
# 53  {0: 'https://conservativebrief.com/former-top-...
# 54  {0: 'https://jennycohn1.medium.com/', 1: 'http...
# 55  {0: 'https://www.highereddive.com/news/lincoln...
# 56  {0: 'https://www.sidneypowell.com/court-filing...
# 57  {0: 'https://www.documentcloud.org/app', 1: 'h...
# 58  {0: 'https://www.france24.com/en/tv-shows/late...
# 59  {0: 'https://www.aps.edu/service-center', 1: '...
# 60  {0: 'https://tips.buzzfeednews.com/', 1: 'http...
# 61  {0: 'https://www.timesofisrael.com/ukraine-pol...
# 62  {0: 'https://americanfaith.com/almost-100-peop...
# 63  {0: 'https://go.constantcontact.com/refer-a-fr...
# 64  {0: 'https://parler.com/feed/402649c4-e7a2-461...

# %%
# Remove duds
df = df.drop([8, 10, 16, 37], axis=0)

# %%
df = df.reset_index().drop('level_0', axis=1)

# %%
df.head()
# Out:
#   index                         site num_links  \
# 0     0        http://dailyexpose.uk        65
# 1     1            http://rumble.com        61
# 2     2           http://harpers.org        67
# 3     3  http://kanekoa.substack.com        20
# 4     6       http://pattyporter.net         3
#
#                                            link_dict
# 0  {0: 'https://dailyexpose.uk/author/rhoda-wilso...
# 1  {0: 'https://rumble.com/v113tdd-nba-playoffs-1...
# 2  {0: 'https://harpers.org/author/davidwonglouie...
# 3  {0: 'https://kanekoa.substack.com/p/exposing-a...
# 4  {0: 'https://www.pattyporter.net/home', 1: 'ht...

# %%
df.to_pickle('./sydney_powell_df.pkl')

# %%
# Create dummy dictionary
# test_df = df.head(2)
# print(test_df['link_dict'][1])

dict1 = {0: 'https://www.bbc.com/sport',
         1: 'https://www.bbc.com/reel',
         2: 'https://www.bbc.com/worklife/article/20210727-the-coded-words-of-job-adverts-that-reveal-important-clues'}

dict2 = {0: 'https://www.nytimes.com/section/sports', 
         1: 'https://www.nytimes.com/interactive/2021/07/27/opinion/jan-6-committee-facts.html?action=click&module=Opinion&pgtype=Homepage', 
         2: 'https://www.nytimes.com/live/2021/07/28/sports/olympics-tokyo-results-medals/?action=click&module=Top%20Stories&pgtype=Homepage'}

test_df = pd.DataFrame.from_dict(
    {
        'index' : [0, 1],
        'site' : ['https://bbc.com/', 'https://nytimes.com/'],
        'num_links' : [69, 420],
        'link_dict' : [dict1, dict2]
    }
)

test_df.to_pickle('./test_df.pkl')
