# %%
import pickle
import pandas as pd

with open('./urls/500_fake_df.pkl', 'rb') as f:
    fake = pickle.load(f)

fake.head()
# Out:
#                               site num_links  \
# index
# 0            http://whatfinger.com       170
# 1      http://missouridownload.com         5
# 2            http://truepundit.com        89
# 3              http://teaparty.org       135
# 4       http://georgiastarnews.com       732
#
#                                                link_dict
# index
# 0      {0: 'https://www.whatfinger.com/', 1: 'https:/...
# 1      {0: 'https://missouridownload.com/', 1: 'https...
# 2      {0: 'https://truepundit.com/#', 1: 'https://tr...
# 3      {0: 'https://www.teaparty.org/', 1: 'https://w...
# 4      {0: 'https://georgiastarnews.com/#home-content...

# %%
with open('./urls/real_df.pkl', 'rb') as f:
    fake = pickle.load(f)

fake.head(50)
# Out:
#                              site num_links  \
# index
# 0           http://www.google.com        26
# 1          http://www.youtube.com       122
# 2            http://www.tmall.com        73
# 3            http://www.baidu.com        20
# 4               http://www.qq.com       235
# 5             http://www.sohu.com       515
# 6           http://www.taobao.com       129
# 7         http://www.facebook.com       128
# 8               http://www.360.cn       124
# 9            http://www.yahoo.com       146
# 10              http://www.jd.com       187
# 11          http://www.amazon.com       219
# 12       http://www.wikipedia.org       479
# 13             http://www.zoom.us       112
# 14           http://www.weibo.com       157
# 15         http://www.sina.com.cn       832
# 16            http://www.live.com        10
# 17          http://www.reddit.com       173
# 18       http://www.microsoft.com       124
# 19         http://www.netflix.com       121
# ...
