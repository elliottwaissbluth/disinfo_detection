# %%
import pickle
from analysis_functions import *

with open('full_df.pkl', 'rb') as f:
    df = pickle.load(f)
f.close()

# %%
results = confidence_interval_logistic_regression(100, df)
# Out:
# 100%|██████████| 100/100 [1:18:29<00:00, 47.09s/it]
#       metric  lower_bound      mean  upper_bound
# 0   accuracy     0.916712  0.930760     0.944808
# 1         f1     0.917186  0.931591     0.945996
# 2  precision     0.889814  0.912691     0.935568
# 3     recall     0.935134  0.951737     0.968340
