# %% [markdown]
# We're interested in what percentage of our domains have which types of meta tags

# %%
import pickle
import pandas as pd
from pathlib import Path

with open('real_counts.pkl', 'rb') as f:
    real_counts = pickle.load(f)
with open('fake_counts.pkl', 'rb') as f:
    fake_counts = pickle.load(f)

print(len(real_counts['keywords']))
# Out:
# 4965

# %%
with open(Path.cwd().parent.parent / 'urls' / 'fake_df.pkl', 'rb') as f:
    fake_df = pickle.load(f)
with open(Path.cwd().parent.parent / 'urls' / 'real_df.pkl', 'rb') as f:
    real_df = pickle.load(f)

original_fake_indices = fake_df.index.values
original_real_indices = real_df.index.values
# Out:
# 2690
# 7941
# [   0    1    2 ... 3400 3401 3402]
#                                         site num_links  \
# index
# 9883                  http://www.qcomment.ru        53
# 9884              http://www.kidstaff.com.ua       143
# 9885                 http://www.haraj.com.sa       290
# 9886                        http://www.vz.ru       245
# 9887                      http://www.ui8.net       107
# 9888                    http://www.romwe.com       102
# 9889                http://www.animepahe.com       103
# 9890               http://www.algoritmika.az         3
# 9892               http://www.abahussain.com       105
# 9893               http://www.policia.gov.co       110
# 9894               http://www.openoffice.org       158
# 9895                 http://www.polyu.edu.hk       161
# 9896                     http://www.exam.net        76
# 9897                     http://www.najiz.sa        33
# 9898                 http://www.missevan.com       201
# ...

# %%
with open(Path.cwd().parent / 'full_df.pkl', 'rb') as f:
    full_df = pickle.load(f)

# %%
len(full_df)
# Out:
# 999
